# %% [markdown]
# ## finetuning process

# %% [markdown]
# ## basic results

# %% [markdown]
# ## after stratided sampling

# %% [markdown]
# # ARMANA-PEYMA finetuning

# %% [markdown]
# # Comparision

# %% [markdown]
# # More Data
